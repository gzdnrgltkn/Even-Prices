# %%
items = [23, 555, 666, 123, 128, 4242, 990]
eitems = []
n=0
while n<len(items):
 if items[n]%2==0:
  eitems.append(items[n])
  n=n+1
 else:
  n=n+1
  continue
print(eitems)
summ=str(sum(eitems))
print('Sum of even prices: '+summ)
# Out:
# [666, 128, 4242, 990]
# Sum of even prices: 6026
